# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

from sklearn import preprocessing
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
from sklearn.neighbors import NearestNeighbors
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt

# %%
columns = ['V2036','V2020','V3071','V2125','V4025','V4049',
                                      'V4127','V4184','V4234','V4235','V4484','V4524','V4525','V4526AA','V2026','V4017',
                                      'V2034','V2040A','V2047','V2132','V3024','V3046','V3058','V3074','YEARQ','V4048',
                                      'V4095','V4051','V4052','V4053','V4054','V4055','V4056','V4057','V4060','V4062',
                                      'V4064','V4066','V4067','V4068','V4070','V4071','V4072','V4073','V4075',
                                     'V4078','V4080','V4081','V4082','V4083','V4084','V4085','V4086','V4087','V4088',
                                      'V4089','V4090','V4091','V4094','V4096','V4097','V4098','V4099','V4100',
                                      'V4101','V4102','V4103','V4104','V4105','V4106','V4107','V4124','V4529',"V4399",'V2033', 'V2071', 'V2072', 'V4016', 'V4364','V4529']

# %%
# Read TSV file into DataFrame
df18 = pd.read_table('37297-0005-Data.tsv',sep="\t",usecols=columns)
df18
# Out:
#         YEARQ  V2020  V2026  V2033  V2034  V2036  V2040A  V2047  V2071  V2072  \
# 0      2018.1      1     13     45      3      1       1     28      1      0
# 1      2018.1      1     13     45      3      1       1     28      1      0
# 2      2018.1      1     17     47      4      2       1     42      4      0
# 3      2018.1      1     15     57      3      1       1     43      1      0
# 4      2018.1      1     16     18      1      2       6     28      5      1
# ...       ...    ...    ...    ...    ...    ...     ...    ...    ...    ...
# 11052  2018.4      1     10     67      1      2       1     28      1      0
# 11053  2018.4      1     16     36      1      2       1     41      2      2
# 11054  2018.4      1     12     59      3      2       1     41      1      0
# 11055  2018.4      1     98     56      1      2       1     42      2      0
# 11056  2018.4      1     13     77      5      1       1     45      1      0
#
#        ...  V4184  V4234  V4235  V4364  V4399  V4484  V4524  V4525  V4526AA  \
# 0      ...      9      9      9  99999      2      9      9      9        2
# 1      ...      9      9      9  99998      2      9      9      9        2
# 2      ...      9      9      9     10      2      9      9      9        2
# 3      ...      1      1      9  99999      2      9      9      9        2
# 4      ...      9      9      9    500      2      9      9      9        2
# ...    ...    ...    ...    ...    ...    ...    ...    ...    ...      ...
# 11052  ...      9      9      9   8000      1      9      9      9        2
# 11053  ...      9      9      9  99999      2      9      9      9        2
# 11054  ...      9      9      9     40      2      9      9      9        2
# 11055  ...      9      3      2   3500      2      9      9      9        2
# 11056  ...      2      2      9  99999      1      9      9      9        2
#
#        V4529
# 0         56
# 1         58
# 2         55
# 3         20
# 4         32
# ...      ...
# 11052     31
# 11053     54
# 11054     55
# 11055     57
# 11056     12
#
# [11057 rows x 79 columns]

# %%
# Read TSV file into DataFrame
df19 = pd.read_table('37645-0005-Data.tsv',sep="\t",usecols=columns)
df19
# Out:
#         YEARQ  V2020  V2026  V2033  V2034  V2036  V2040A  V2047  V2071  V2072  \
# 0      2019.1      1     12     76      1      2       1     40      3      0
# 1      2019.1      1     18     59      1      2       1     42      2      0
# 2      2019.1      1     12     32      1      2       1     28      2      3
# 3      2019.1      1     10     60      3      1       2     43      1      0
# 4      2019.1      1     10     60      3      1       2     43      1      0
# ...       ...    ...    ...    ...    ...    ...     ...    ...    ...    ...
# 10401  2019.4      1     98     28      5      1       1     28      1      0
# 10402  2019.4      1     15     40      1      2       1     42      3      2
# 10403  2019.4      1     98     55      5      2       1     42      2      0
# 10404  2019.4      1     98     43      1      2       4     27      2      0
# 10405  2019.4      1     16     56      1      2       4     42      4      0
#
#        ...  V4184  V4234  V4235  V4364  V4399  V4484  V4524  V4525  V4526AA  \
# 0      ...      9      9      9  99999      2      9      9      9        2
# 1      ...      9      9      9  99999      1      9      9      9        2
# 2      ...      9      9      9     20      2      9      9      9        2
# 3      ...      9      9      9    300      2      9      9      9        2
# 4      ...      9      9      9  99998      2      9      9      9        2
# ...    ...    ...    ...    ...    ...    ...    ...    ...    ...      ...
# 10401  ...      9      9      9    200      2      9      9      9        2
# 10402  ...      1      1      9    200      2      1      9      9        2
# 10403  ...      1      1      9  99999      1      9      9      9        2
# 10404  ...      9      9      9  99999      1      9      9      9        2
# 10405  ...      9      9      9  99998      1      9      9      9        2
#
#        V4529
# 0         54
# 1         59
# 2         55
# 3         57
# 4         58
# ...      ...
# 10401     56
# 10402     56
# 10403     12
# 10404     41
# 10405     58
#
# [10406 rows x 79 columns]

# %%
#concatenated file
df20 = pd.read_table('38090-0005-Data.tsv',sep="\t",usecols=columns)
df20
# Out:
#        YEARQ  V2020  V2026  V2033  V2034  V2036  V2040A  V2047  V2071  V2072  \
# 0     2020.1      1     98     62      3      2       1     42      1      0
# 1     2020.1     12     98     20      5      1       1     41      2      0
# 2     2020.1     12     98     20      5      1       1     41      2      0
# 3     2020.1      1      9     63      5      2       1     42      1      0
# 4     2020.1      1     16     51      1      2       5     10      4      0
# ...      ...    ...    ...    ...    ...    ...     ...    ...    ...    ...
# 8038  2020.4      5      3     66      1      2       1     40      3      0
# 8039  2020.4      1     12     22      2      2       1     40      2      0
# 8040  2020.4      1     12     22      2      2       1     40      2      0
# 8041  2020.4      1     18     31      1      1       1     45      2      1
# 8042  2020.4      5     16     30      5      2       1     28      3      0
#
#       ...  V4184  V4234  V4235  V4364  V4399  V4484  V4524  V4525  V4526AA  \
# 0     ...      9      9      9     10      2      9      9      9        2
# 1     ...      9      9      9    100      2      9      9      9        2
# 2     ...      9      9      9     20      2      9      9      9        2
# 3     ...      9      9      9      2      2      9      9      9        2
# 4     ...      9      9      9   5000      1      9      9      9        2
# ...   ...    ...    ...    ...    ...    ...    ...    ...    ...      ...
# 8038  ...      1      1      9  99999      1      1      9      9        2
# 8039  ...      1      1      9  99999      1      9      9      9        2
# 8040  ...      1      1      9  99999      1      9      9      9        2
# 8041  ...      9      9      9     10      2      9      9      9        2
# 8042  ...      9      9      9  99998      2      9      9      9        2
#
#       V4529
# 0        55
# 1        56
# 2        55
# 3        54
# 4        57
# ...     ...
# 8038     17
# 8039     20
# 8040     20
# 8041     54
# 8042     58
#
# [8043 rows x 79 columns]

# %%
df = pd.concat([df18,df19,df20])
df
# Out:
#        YEARQ  V2020  V2026  V2033  V2034  V2036  V2040A  V2047  V2071  V2072  \
# 0     2018.1      1     13     45      3      1       1     28      1      0
# 1     2018.1      1     13     45      3      1       1     28      1      0
# 2     2018.1      1     17     47      4      2       1     42      4      0
# 3     2018.1      1     15     57      3      1       1     43      1      0
# 4     2018.1      1     16     18      1      2       6     28      5      1
# ...      ...    ...    ...    ...    ...    ...     ...    ...    ...    ...
# 8038  2020.4      5      3     66      1      2       1     40      3      0
# 8039  2020.4      1     12     22      2      2       1     40      2      0
# 8040  2020.4      1     12     22      2      2       1     40      2      0
# 8041  2020.4      1     18     31      1      1       1     45      2      1
# 8042  2020.4      5     16     30      5      2       1     28      3      0
#
#       ...  V4184  V4234  V4235  V4364  V4399  V4484  V4524  V4525  V4526AA  \
# 0     ...      9      9      9  99999      2      9      9      9        2
# 1     ...      9      9      9  99998      2      9      9      9        2
# 2     ...      9      9      9     10      2      9      9      9        2
# 3     ...      1      1      9  99999      2      9      9      9        2
# 4     ...      9      9      9    500      2      9      9      9        2
# ...   ...    ...    ...    ...    ...    ...    ...    ...    ...      ...
# 8038  ...      1      1      9  99999      1      1      9      9        2
# 8039  ...      1      1      9  99999      1      9      9      9        2
# 8040  ...      1      1      9  99999      1      9      9      9        2
# 8041  ...      9      9      9     10      2      9      9      9        2
# 8042  ...      9      9      9  99998      2      9      9      9        2
#
#       V4529
# 0        56
# 1        58
# 2        55
# 3        20
# 4        32
# ...     ...
# 8038     17
# 8039     20
# 8040     20
# 8041     54
# 8042     58
#
# [29506 rows x 79 columns]

# %%
#Target
df = df.loc[df["V4399"] != 3]
df = df.loc[df["V4399"] != 8]
print(df["V4399"].value_counts())
# Out:
# 2    18673
# 1    10445
# Name: V4399, dtype: int64

# %%
features = df[['V2036','V2020','V3071','V2125','V4025','V4049',
                                      'V4127','V4184','V4234','V4235','V4484','V4524','V4525','V4526AA','V2026','V4017',
                                      'V2034','V2040A','V2047','V2132','V3024','V3046','V3058','V3074','YEARQ','V4048',
                                      'V4095','V4051','V4052','V4053','V4054','V4055','V4056','V4057','V4060','V4062',
                                      'V4064','V4066','V4067','V4068','V4070','V4071','V4072','V4073','V4075',
                                     'V4078','V4080','V4081','V4082','V4083','V4084','V4085','V4086','V4087','V4088',
                                      'V4089','V4090','V4091','V4094','V4096','V4097','V4098','V4099','V4100',
                                      'V4101','V4102','V4103','V4104','V4105','V4106','V4107','V4124','V4529']]

# %%
data2 = pd.get_dummies(df, columns=['V2036','V2020','V3071','V2125','V4025','V4049',
                                      'V4127','V4184','V4234','V4235','V4484','V4524','V4525','V4526AA','V2026','V4017',
                                      'V2034','V2040A','V2047','V2132','V3024','V3046','V3058','V3074','YEARQ','V4048',
                                      'V4095','V4051','V4052','V4053','V4054','V4055','V4056','V4057','V4060','V4062',
                                      'V4064','V4066','V4067','V4068','V4070','V4071','V4072','V4073','V4075',
                                     'V4078','V4080','V4081','V4082','V4083','V4084','V4085','V4086','V4087','V4088',
                                      'V4089','V4090','V4091','V4094','V4096','V4097','V4098','V4099','V4100',
                                      'V4101','V4102','V4103','V4104','V4105','V4106','V4107','V4124','V4529'])

feature_names = ['V2036_1', 'V2036_2','V2020_1','V2020_2','V2020_3','V2020_4','V2020_5'
                ,'V2020_6','V2020_7','V2020_8','V2020_11','V2020_12','V3071_1','V3071_2','V2125_1','V2125_2','V4025_1',
                 'V4025_2','V4049_1','V4049_2','V4127_1','V4127_2','V4184_1','V4184_2','V4234_1','V4234_2','V4235_1',
                 'V4235_2','V4484_1','V4484_2','V4524_1','V4524_2','V4525_1','V4525_2','V4526AA_1','V4526AA_2',
                 'V4526AA_3','V2026_1','V2026_2','V2026_3','V2026_4','V2026_5','V2026_6','V2026_7','V2026_8','V2026_9',
                 'V2026_10','V2026_11','V2026_12','V2026_13','V2026_15','V2026_16','V2026_17','V2026_18','V2033','V2071',
                 'V2072','V4016','V4364','V4017_1','V4017_2','V2034_1','V2034_2','V2034_3','V2034_4','V2034_5','V2040A_1',
                'V2040A_5','V2040A_3','V2040A_4','V2040A_2','V2040A_6','V2040A_7','V2040A_8','V2040A_10','V2040A_15',
                 'V2040A_11','V2040A_14','V2040A_19','V2040A_16','V2040A_12','V2040A_18','V2040A_17','V2040A_13',
                 'V2040A_9','V2040A_20','V2047_42','V2047_41','V2047_10','V2047_28','V2047_27','V2047_43','V2047_44',
                 'V2047_11','V2047_40','V2047_9','V2047_45','V2047_7','V2047_8','V2047_0','V2047_6','V2047_3','V2047_2',
                 'V2047_1','V2047_4','V2047_5','V2132_4','V2132_1','V2132_2','V2132_3','V2132_0','V3024_1','V3024_2','V3046_2',
                 'V3046_1','V3046_3','V3058_1','V3058_2','V3074_11','V3074_12','V3074_27','V3074_2','V3074_8','V3074_9',
                'V3074_16','V3074_3','V3074_10','V3074_17','V3074_14','V3074_18','V3074_6','V3074_1','V3074_20','V3074_5',
                'V3074_22','V3074_24','V3074_21','V3074_25','V3074_13','YEARQ_2020.1','YEARQ_2020.2','YEARQ_2020.3',
                 'YEARQ_2020.4','V4048_1','V4048_2','V4095_0','V4095_1','V4051_0','V4051_1','V4052_0','V4052_1','V4053_0',
                'V4053_1','V4054_0','V4054_1','V4055_0','V4055_1','V4056_0','V4056_1','V4057_0','V4057_1','V4060_1',
                 'V4060_2','V4062_1','V4062_2','V4064_1','V4064_2','V4066_0','V4066_1','V4067_0','V4067_1','V4068_0','V4068_1',
                 'V4070_0','V4070_1','V4071_0','V4071_1','V4072_0','V4072_1','V4073_0','V4073_1','V4075_0','V4075_1','V4078_0',
                 'V4078_1','V4080_0', 'V4080_1','V4081_0','V4081_1','V4082_0','V4082_1','V4083_0','V4083_1','V4084_0','V4084_1',
                 'V4085_0','V4085_1','V4086_0','V4086_1','V4087_0','V4087_1','V4088_0','V4088_1','V4089_0','V4089_1',
                 'V4090_0','V4090_1','V4091_0','V4091_1','V4094_0','V4094_1','V4096_0','V4096_1',
                'V4097_0','V4097_1','V4098_0','V4098_1','V4099_0','V4099_1','V4100_0','V4100_1','V4101_0','V4101_1',
                'V4102_0','V4102_1','V4103_0','V4103_1','V4104_0','V4104_1','V4105_0','V4105_1','V4106_0','V4106_1',
                'V4107_0','V4107_1','V4124_2','V4124_4','V4124_7','V4124_8','V4124_10','V4529_55','V4529_56','V4529_54','V4529_57',
                'V4529_17','V4529_11','V4529_58','V4529_12','V4529_40','V4529_14','V4529_32','V4529_10','V4529_1','V4529_41','V4529_31',
                'V4529_59','V4529_20','V4529_33','V4529_13','V4529_5','V4529_7','V4529_15','V4529_9','V4529_2','V4529_23','V4529_6',
                'V4529_19','V4529_8','V4529_4','V4529_18','V4529_16','V4529_3','V4529_22','V4529_21']

X2 = data2[feature_names]
y2 = data2.V4399

# %%
df
# Out:
#        YEARQ  V2020  V2026  V2033  V2034  V2036  V2040A  V2047  V2071  V2072  \
# 0     2018.1      1     13     45      3      1       1     28      1      0
# 1     2018.1      1     13     45      3      1       1     28      1      0
# 2     2018.1      1     17     47      4      2       1     42      4      0
# 3     2018.1      1     15     57      3      1       1     43      1      0
# 4     2018.1      1     16     18      1      2       6     28      5      1
# ...      ...    ...    ...    ...    ...    ...     ...    ...    ...    ...
# 8038  2020.4      5      3     66      1      2       1     40      3      0
# 8039  2020.4      1     12     22      2      2       1     40      2      0
# 8040  2020.4      1     12     22      2      2       1     40      2      0
# 8041  2020.4      1     18     31      1      1       1     45      2      1
# 8042  2020.4      5     16     30      5      2       1     28      3      0
#
#       ...  V4184  V4234  V4235  V4364  V4399  V4484  V4524  V4525  V4526AA  \
# 0     ...      9      9      9  99999      2      9      9      9        2
# 1     ...      9      9      9  99998      2      9      9      9        2
# 2     ...      9      9      9     10      2      9      9      9        2
# 3     ...      1      1      9  99999      2      9      9      9        2
# 4     ...      9      9      9    500      2      9      9      9        2
# ...   ...    ...    ...    ...    ...    ...    ...    ...    ...      ...
# 8038  ...      1      1      9  99999      1      1      9      9        2
# 8039  ...      1      1      9  99999      1      9      9      9        2
# 8040  ...      1      1      9  99999      1      9      9      9        2
# 8041  ...      9      9      9     10      2      9      9      9        2
# 8042  ...      9      9      9  99998      2      9      9      9        2
#
#       V4529
# 0        56
# 1        58
# 2        55
# 3        20
# 4        32
# ...     ...
# 8038     17
# 8039     20
# 8040     20
# 8041     54
# 8042     58
#
# [29118 rows x 79 columns]

# %%
target = df[['V4399']]
scaler = preprocessing.StandardScaler().fit(X2)
scaled_inputs = scaler.transform(X2)
scaled_inputs
# Out:
# array([[ 1.69183804, -1.69183804,  0.19926309, ..., -0.03469081,
#         -0.01657769, -0.02416966],
#        [ 1.69183804, -1.69183804,  0.19926309, ..., -0.03469081,
#         -0.01657769, -0.02416966],
#        [-0.59107313,  0.59107313,  0.19926309, ..., -0.03469081,
#         -0.01657769, -0.02416966],
#        ...,
#        [-0.59107313,  0.59107313,  0.19926309, ..., -0.03469081,
#         -0.01657769, -0.02416966],
#        [ 1.69183804, -1.69183804,  0.19926309, ..., -0.03469081,
#         -0.01657769, -0.02416966],
#        [-0.59107313,  0.59107313, -5.01849099, ..., -0.03469081,
#         -0.01657769, -0.02416966]])

# %%
target
# Out:
#       V4399
# 0         2
# 1         2
# 2         2
# 3         2
# 4         2
# ...     ...
# 8038      1
# 8039      1
# 8040      1
# 8041      2
# 8042      2
#
# [29118 rows x 1 columns]

# %%
#splitting data to train and test splits
X_train, X_test, y_train, y_test = train_test_split(scaled_inputs, y2, test_size=0.2, random_state=42)
X_train
print(y_test)
# Out:
# 4210     2
# 1846     2
# 9923     2
# 2915     1
# 7394     2
#         ..
# 3203     1
# 6616     2
# 9308     2
# 118      1
# 10482    2
# Name: V4399, Length: 5824, dtype: int64

# %%
#training a logistic regression model
clf = LogisticRegression(random_state=0).fit(X_train, y_train)
# Out:
# /opt/pub/eb/apps/all/DavidsonJupyter/2021-common-GCCcore-10.2.0/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
clf.score(X_test,y_test)
# Out:
# 0.7008928571428571

# %%
predictions = clf.predict(X_test)
print(predictions)
print(y_test)
# Out:
# [1 2 2 ... 2 2 2]
# 4210     2
# 1846     2
# 9923     2
# 2915     1
# 7394     2
#         ..
# 3203     1
# 6616     2
# 9308     2
# 118      1
# 10482    2
# Name: V4399, Length: 5824, dtype: int64

# %%
clf.score(X_train,y_train)
# Out:
# 0.7118571305915686

# %%
#Random Forest
rmf = RandomForestClassifier(n_estimators=450, max_depth=30,random_state=0,criterion="entropy")
rmf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=30, n_estimators=450,
#                        random_state=0)

# %%
pred =rmf.predict(X_test)

# %%
rmf.score(X_train,y_train)
# Out:
# 0.9220829398128273

# %%
rmf.score(X_test,y_test)
# Out:
# 0.7244162087912088

# %%
y_pred = rmf.predict(X_test)

# Evaluate performance
from sklearn.metrics import classification_report, confusion_matrix
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.72      0.39      0.50      2106
#            2       0.72      0.91      0.81      3718
#
#     accuracy                           0.72      5824
#    macro avg       0.72      0.65      0.66      5824
# weighted avg       0.72      0.72      0.70      5824
#
# [[ 819 1287]
#  [ 325 3393]]

# %%
# Define hyperparameter grid
param_grid = {
    'n_estimators': [250,300,350,400,450],
    'max_depth': [20,25,30,35,40,None]
}

# Search over hyperparameter grid
from sklearn.model_selection import GridSearchCV
grid_search = GridSearchCV(rmf, param_grid=param_grid, cv=5)
grid_search.fit(X_train, y_train)

# Print best hyperparameters
print(grid_search.best_params_)
# Out:
# {'max_depth': 30, 'n_estimators': 450}

# %%
# plotting n_estimators

score_array=[]
for estimator_value in range(150,450,10):
    model = RandomForestClassifier(n_estimators=estimator_value, max_depth=25,random_state=0,criterion="entropy").fit(X_train,y_train)
    score_array.append(model.score(X_test, y_test))

plt.xlabel('estimators')
plt.ylabel('score')
plt.plot(np.arange(150,450,10),score_array,"o-")
